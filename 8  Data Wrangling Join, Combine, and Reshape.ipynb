# %%
# Aug 27

# %%
import pandas as pd
import numpy as np

# %%
 data = pd.Series(np.random.uniform(size=9),
   ....:                  index=[["a", "a", "a", "b", "b", "c", "c", "d", "d"],
   ....:                         [1, 2, 3, 1, 3, 1, 2, 2, 3]])

# %%
data.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )

# %%
data
# Out:
# a  1    0.840245
#    2    0.274401
#    3    0.117516
# b  1    0.264266
#    3    0.567017
# c  1    0.841036
#    2    0.281786
# d  2    0.922926
#    3    0.823317
# dtype: float64

# %%
data["a"]
# Out:
# 1    0.840245
# 2    0.274401
# 3    0.117516
# dtype: float64

# %%
data["b":"c"]
# Out:
# b  1    0.264266
#    3    0.567017
# c  1    0.841036
#    2    0.281786
# dtype: float64

# %%
data.loc[["b", "d"]]
# Out:
# b  1    0.264266
#    3    0.567017
# d  2    0.922926
#    3    0.823317
# dtype: float64

# %%
data[:,1]
# Out:
# a    0.840245
# b    0.264266
# c    0.841036
# dtype: float64

# %%
data[:,2]
# Out:
# a    0.274401
# c    0.281786
# d    0.922926
# dtype: float64

# %%
data[:,3]
# Out:
# a    0.117516
# b    0.567017
# d    0.823317
# dtype: float64

# %%
data["a",3]
# Out:
# 0.11751559657563104

# %%
data.unstack()
# Out:
#           1         2         3
# a  0.840245  0.274401  0.117516
# b  0.264266       NaN  0.567017
# c  0.841036  0.281786       NaN
# d       NaN  0.922926  0.823317

# %%
data.unstack().stack()
# Out:
# a  1    0.840245
#    2    0.274401
#    3    0.117516
# b  1    0.264266
#    3    0.567017
# c  1    0.841036
#    2    0.281786
# d  2    0.922926
#    3    0.823317
# dtype: float64

# %%
frame = pd.DataFrame(np.arange(12).reshape((4, 3)),
   ....:                      index=[["a", "a", "b", "b"], [1, 2, 1, 2]],
   ....:                      columns=[["Ohio", "Ohio", "Colorado"],
   ....:                               ["Green", "Red", "Green"]])

# %%
frame
# Out:
#      Ohio     Colorado
#     Green Red    Green
# a 1     0   1        2
#   2     3   4        5
# b 1     6   7        8
#   2     9  10       11

# %%
frame.index.names = ["key1", "key2"]

# %%
frame
# Out:
#            Ohio     Colorado
#           Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.columns.names = ["state", "color"]

# %%
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.index.nlevels
# Out:
# 2

# %%
frame["Ohio"]
# Out:
# color      Green  Red
# key1 key2
# a    1         0    1
#      2         3    4
# b    1         6    7
#      2         9   10

# %%
pd.MultiIndex.from_arrays([["Ohio", "Ohio", "Colorado"],
                          ["Green", "Red", "Green"]],
                          names=["state", "color"])
# Out:
# MultiIndex([(    'Ohio', 'Green'),
#             (    'Ohio',   'Red'),
#             ('Colorado', 'Green')],
#            names=['state', 'color'])

# %%
frame.swaplevel("key1", "key2")
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
# 2    a        3   4        5
# 1    b        6   7        8
# 2    b        9  10       11

# %%
frame.groupby(level="key2").sum()
# Out:
# state  Ohio     Colorado
# color Green Red    Green
# key2
# 1         6   8       10
# 2        12  14       16

# %%
frame.sum()
# Out:
# state     color
# Ohio      Green    18
#           Red      22
# Colorado  Green    26
# dtype: int64

# %%
frame.groupby(level="color", axis="columns").sum()
# Out:
# color      Green  Red
# key1 key2
# a    1         2    1
#      2         8    4
# b    1        14    7
#      2        20   10

# %%
frame = pd.DataFrame({"a": range(7), "b": range(7, 0, -1),
   ....:                       "c": ["one", "one", "one", "two", "two",
   ....:                             "two", "two"],
   ....:                       "d": [0, 1, 2, 0, 1, 2, 3]})

# %%
frame
# Out:
#    a  b    c  d
# 0  0  7  one  0
# 1  1  6  one  1
# 2  2  5  one  2
# 3  3  4  two  0
# 4  4  3  two  1
# 5  5  2  two  2
# 6  6  1  two  3

# %%
frame2 = frame.set_index(["c", "d"])

# %%
frame2
# Out:
#        a  b
# c   d
# one 0  0  7
#     1  1  6
#     2  2  5
# two 0  3  4
#     1  4  3
#     2  5  2
#     3  6  1

# %%
frame.set_index(["c", "d"], drop=False)
# Out:
#        a  b    c  d
# c   d
# one 0  0  7  one  0
#     1  1  6  one  1
#     2  2  5  one  2
# two 0  3  4  two  0
#     1  4  3  two  1
#     2  5  2  two  2
#     3  6  1  two  3

# %%
frame2.reset_index()
# Out:
#      c  d  a  b
# 0  one  0  0  7
# 1  one  1  1  6
# 2  one  2  2  5
# 3  two  0  3  4
# 4  two  1  4  3
# 5  two  2  5  2
# 6  two  3  6  1

# %%
df1 = pd.DataFrame({"key": ["b", "b", "a", "c", "a", "a", "b"],
   ....:                     "data1": pd.Series(range(7), dtype="Int64")})

# %%
df2 = pd.DataFrame({"key": ["a", "b", "d"],
   ....:                     "data2": pd.Series(range(3), dtype="Int64")})

# %%
pd.merge(df1, df2)
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
df1.merge(df2)
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
pd.merge(df1, df2, on="key")
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
df3 = pd.DataFrame({"lkey": ["b", "b", "a", "c", "a", "a", "b"],
   ....:                     "data1": pd.Series(range(7), dtype="Int64")})

# %%
df4 = pd.DataFrame({"rkey": ["a", "b", "d"],
   ....:                     "data2": pd.Series(range(3), dtype="Int64")})

# %%
pd.merge(df3, df4, left_on="lkey", right_on="rkey")
# Out:
#   lkey  data1 rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    b      6    b      1
# 3    a      2    a      0
# 4    a      4    a      0
# 5    a      5    a      0

# %%
pd.merge(df1, df2, how="outer")
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0
# 6   c      3   <NA>
# 7   d   <NA>      2

# %%
pd.merge(df3, df4, left_on="lkey", right_on="rkey", how="outer")
# Out:
#   lkey  data1 rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    b      6    b      1
# 3    a      2    a      0
# 4    a      4    a      0
# 5    a      5    a      0
# 6    c      3  NaN   <NA>
# 7  NaN   <NA>    d      2

# %%
pd.merge(df3, df4, left_on="lkey", right_on="rkey", how="left")
# Out:
#   lkey  data1 rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    a      2    a      0
# 3    c      3  NaN   <NA>
# 4    a      4    a      0
# 5    a      5    a      0
# 6    b      6    b      1

# %%
data = pd.read_csv("pydata-book-3rd-edition/examples/macrodata.csv")

# %%
data
# Out:
#      year  quarter    realgdp  realcons   realinv  realgovt  realdpi      cpi  \
# 0    1959        1   2710.349    1707.4   286.898   470.045   1886.9   28.980
# 1    1959        2   2778.801    1733.7   310.859   481.301   1919.7   29.150
# 2    1959        3   2775.488    1751.8   289.226   491.260   1916.4   29.350
# 3    1959        4   2785.204    1753.7   299.356   484.052   1931.3   29.370
# 4    1960        1   2847.699    1770.5   331.722   462.199   1955.5   29.540
# ..    ...      ...        ...       ...       ...       ...      ...      ...
# 198  2008        3  13324.600    9267.7  1990.693   991.551   9838.3  216.889
# 199  2008        4  13141.920    9195.3  1857.661  1007.273   9920.4  212.174
# 200  2009        1  12925.410    9209.2  1558.494   996.287   9926.4  212.671
# 201  2009        2  12901.504    9189.0  1456.678  1023.528  10077.5  214.469
# 202  2009        3  12990.341    9256.0  1486.398  1044.088  10040.6  216.385
#
#          m1  tbilrate  unemp      pop  infl  realint
# 0     139.7      2.82    5.8  177.146  0.00     0.00
# 1     141.7      3.08    5.1  177.830  2.34     0.74
# 2     140.5      3.82    5.3  178.657  2.74     1.09
# 3     140.0      4.33    5.6  179.386  0.27     4.06
# 4     139.6      3.50    5.2  180.007  2.31     1.19
# ..      ...       ...    ...      ...   ...      ...
# 198  1474.7      1.17    6.0  305.270 -3.16     4.33
# 199  1576.5      0.12    6.9  305.952 -8.79     8.91
# 200  1592.8      0.22    8.1  306.547  0.94    -0.71
# 201  1653.6      0.18    9.2  307.226  3.37    -3.19
# 202  1673.9      0.12    9.6  308.013  3.56    -3.44
#
# [203 rows x 14 columns]

# %%
data = data.loc[:, ["year", "quarter", "realgdp", "infl", "unemp"]]

# %%
data.head()
# Out:
#    year  quarter   realgdp  infl  unemp
# 0  1959        1  2710.349  0.00    5.8
# 1  1959        2  2778.801  2.34    5.1
# 2  1959        3  2775.488  2.74    5.3
# 3  1959        4  2785.204  0.27    5.6
# 4  1960        1  2847.699  2.31    5.2

# %%
periods = pd.PeriodIndex(year=data.pop("year"),
   .....:                          quarter=data.pop("quarter"),
   .....:                          name="date")

# %%
periods
# Out:
# PeriodIndex(['1959Q1', '1959Q2', '1959Q3', '1959Q4', '1960Q1', '1960Q2',
#              '1960Q3', '1960Q4', '1961Q1', '1961Q2',
#              ...
#              '2007Q2', '2007Q3', '2007Q4', '2008Q1', '2008Q2', '2008Q3',
#              '2008Q4', '2009Q1', '2009Q2', '2009Q3'],
#             dtype='period[Q-DEC]', name='date', length=203)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=203, step=1)

# %%
data.head()
# Out:
#     realgdp  infl  unemp
# 0  2710.349  0.00    5.8
# 1  2778.801  2.34    5.1
# 2  2775.488  2.74    5.3
# 3  2785.204  0.27    5.6
# 4  2847.699  2.31    5.2

# %%
periods.to_timestamp("D")
# Out:
# DatetimeIndex(['1959-01-01', '1959-04-01', '1959-07-01', '1959-10-01',
#                '1960-01-01', '1960-04-01', '1960-07-01', '1960-10-01',
#                '1961-01-01', '1961-04-01',
#                ...
#                '2007-04-01', '2007-07-01', '2007-10-01', '2008-01-01',
#                '2008-04-01', '2008-07-01', '2008-10-01', '2009-01-01',
#                '2009-04-01', '2009-07-01'],
#               dtype='datetime64[ns]', name='date', length=203, freq='QS-OCT')

# %%
data.index = periods.to_timestamp("D")

# %%
data.head()
# Out:
#              realgdp  infl  unemp
# date
# 1959-01-01  2710.349  0.00    5.8
# 1959-04-01  2778.801  2.34    5.1
# 1959-07-01  2775.488  2.74    5.3
# 1959-10-01  2785.204  0.27    5.6
# 1960-01-01  2847.699  2.31    5.2

# %%
data = data.reindex(columns=["realgdp", "infl", "unemp"])

# %%
data.columns.name = "item"

# %%
data.head()
# Out:
# item         realgdp  infl  unemp
# date
# 1959-01-01  2710.349  0.00    5.8
# 1959-04-01  2778.801  2.34    5.1
# 1959-07-01  2775.488  2.74    5.3
# 1959-10-01  2785.204  0.27    5.6
# 1960-01-01  2847.699  2.31    5.2

# %%
long_data = (data.stack()
   .....:              .reset_index())

# %%
long_data
# Out:
#           date     item          0
# 0   1959-01-01  realgdp   2710.349
# 1   1959-01-01     infl      0.000
# 2   1959-01-01    unemp      5.800
# 3   1959-04-01  realgdp   2778.801
# 4   1959-04-01     infl      2.340
# ..         ...      ...        ...
# 604 2009-04-01     infl      3.370
# 605 2009-04-01    unemp      9.200
# 606 2009-07-01  realgdp  12990.341
# 607 2009-07-01     infl      3.560
# 608 2009-07-01    unemp      9.600
#
# [609 rows x 3 columns]

# %%
long_data = (data.stack()
   .....:              .reset_index()
   .....:              .rename(columns={0: "value"}))

# %%
long_data.head()
# Out:
#         date     item     value
# 0 1959-01-01  realgdp  2710.349
# 1 1959-01-01     infl     0.000
# 2 1959-01-01    unemp     5.800
# 3 1959-04-01  realgdp  2778.801
# 4 1959-04-01     infl     2.340

# %%
pivoted = long_data.pivot(index="date", columns="item",
   .....:                           values="value")

# %%
pivoted.head()
# Out:
# item        infl   realgdp  unemp
# date
# 1959-01-01  0.00  2710.349    5.8
# 1959-04-01  2.34  2778.801    5.1
# 1959-07-01  2.74  2775.488    5.3
# 1959-10-01  0.27  2785.204    5.6
# 1960-01-01  2.31  2847.699    5.2

# %%
long_data["value2"] = np.random.standard_normal(len(long_data))

# %%
long_data[:10]
# Out:
#         date     item     value    value2
# 0 1959-01-01  realgdp  2710.349  0.747009
# 1 1959-01-01     infl     0.000 -0.960301
# 2 1959-01-01    unemp     5.800  0.402984
# 3 1959-04-01  realgdp  2778.801  1.528912
# 4 1959-04-01     infl     2.340 -2.164558
# 5 1959-04-01    unemp     5.100  1.029854
# 6 1959-07-01  realgdp  2775.488 -0.742889
# 7 1959-07-01     infl     2.740  1.306846
# 8 1959-07-01    unemp     5.300 -1.012119
# 9 1959-10-01  realgdp  2785.204 -0.307892

# %%
pivoted = long_data.pivot(index="date", columns="item")

# %%
pivoted.head()
# Out:
#            value                    value2
# item        infl   realgdp unemp      infl   realgdp     unemp
# date
# 1959-01-01  0.00  2710.349   5.8 -0.960301  0.747009  0.402984
# 1959-04-01  2.34  2778.801   5.1 -2.164558  1.528912  1.029854
# 1959-07-01  2.74  2775.488   5.3  1.306846 -0.742889 -1.012119
# 1959-10-01  0.27  2785.204   5.6 -0.868296 -0.307892  0.945483
# 1960-01-01  2.31  2847.699   5.2 -0.944520 -0.138465 -1.373008

# %%
pivoted["value"].head()
# Out:
# item        infl   realgdp  unemp
# date
# 1959-01-01  0.00  2710.349    5.8
# 1959-04-01  2.34  2778.801    5.1
# 1959-07-01  2.74  2775.488    5.3
# 1959-10-01  0.27  2785.204    5.6
# 1960-01-01  2.31  2847.699    5.2

# %%
unstacked = long_data.set_index(["date", "item"]).unstack(level="item")

# %%
unstacked.head()
# Out:
#            value                    value2
# item        infl   realgdp unemp      infl   realgdp     unemp
# date
# 1959-01-01  0.00  2710.349   5.8 -0.960301  0.747009  0.402984
# 1959-04-01  2.34  2778.801   5.1 -2.164558  1.528912  1.029854
# 1959-07-01  2.74  2775.488   5.3  1.306846 -0.742889 -1.012119
# 1959-10-01  0.27  2785.204   5.6 -0.868296 -0.307892  0.945483
# 1960-01-01  2.31  2847.699   5.2 -0.944520 -0.138465 -1.373008

# %%
unstacked.stack()
# Out:
#                         value    value2
# date       item
# 1959-01-01 infl         0.000 -0.960301
#            realgdp   2710.349  0.747009
#            unemp        5.800  0.402984
# 1959-04-01 infl         2.340 -2.164558
#            realgdp   2778.801  1.528912
# ...                       ...       ...
# 2009-04-01 realgdp  12901.504 -0.030049
#            unemp        9.200 -0.072170
# 2009-07-01 infl         3.560 -1.178161
#            realgdp  12990.341  0.560812
#            unemp        9.600  0.873003
#
# [609 rows x 2 columns]

# %%
df = pd.DataFrame({"key": ["foo", "bar", "baz"],
   .....:                    "A": [1, 2, 3],
   .....:                    "B": [4, 5, 6],
   .....:                    "C": [7, 8, 9]})

# %%
df
# Out:
#    key  A  B  C
# 0  foo  1  4  7
# 1  bar  2  5  8
# 2  baz  3  6  9

# %%
melted = pd.melt(df, id_vars="key")

# %%
melted
# Out:
#    key variable  value
# 0  foo        A      1
# 1  bar        A      2
# 2  baz        A      3
# 3  foo        B      4
# 4  bar        B      5
# 5  baz        B      6
# 6  foo        C      7
# 7  bar        C      8
# 8  baz        C      9

# %%
reshaped = melted.pivot(index="key", columns="variable",
   .....:                         values="value")

# %%
reshaped
# Out:
# variable  A  B  C
# key
# bar       2  5  8
# baz       3  6  9
# foo       1  4  7

# %%
reshaped.reset_index()
# Out:
# variable  key  A  B  C
# 0         bar  2  5  8
# 1         baz  3  6  9
# 2         foo  1  4  7
